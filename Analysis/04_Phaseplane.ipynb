# %% [markdown]
# Phenotype phase plane analysis

# %%
from cobra.flux_analysis.phenotype_phase_plane import production_envelope
# %run 01_Model_CFE.ipynb
# Out:
# ADS: frdp_c --> AMOR + ppi_c
# CPR1_CYP71AV1: AMOR + h_c + nadph_c + o2_c --> AAOH + h2o_c + nadp_c
# ADH1: AAOH + nad_c --> AAld + h_c + nadh_c
# ALDH1: AAld + h2o_c + nadp_c --> AA + h_c + nadph_c

# %% [markdown]
# Defining the glucose content in the YEPD media:

# %%
#Changning flux of succrose
Medium=iMM904.medium
Medium['EX_sucr_e']=20
iMM904.reactions.EX_sucr_e.bounds=-20,1000

# %% [markdown]
# Constructing the phenotype phase plane plot for the biomass objective:

# %%
PPP_biomass = production_envelope(iMM904,
                    reactions=[iMM904.reactions.EX_sucr_e],
                    objective=iMM904.reactions.BIOMASS_SC5_notrace)
PPP_biomass
# Out:
#              carbon_source  flux_minimum  carbon_yield_minimum  \
# 0   EX_glc__D_e, EX_sucr_e           0.0          1.614638e-15
# 1   EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 2   EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 3   EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 4   EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 5   EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 6   EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 7   EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 8   EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 9   EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 10  EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 11  EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 12  EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# 13  EX_glc__D_e, EX_sucr_e           0.0          0.000000e+00
# ...

# %%
PPP_biomass.plot(x='EX_sucr_e', y='flux_maximum', ylabel="Biomass")
# Out:
# <AxesSubplot:xlabel='EX_sucr_e', ylabel='Biomass'>

# %% [markdown]
# Constructing the phenotype phase plane plot for artemisinic acid:

# %%
PPP_AA = production_envelope(iMM904,
                    reactions=[iMM904.reactions.EX_sucr_e],
                    objective=iMM904.reactions.ALDH1)
PPP_AA
# Out:
#              carbon_source  flux_minimum  carbon_yield_minimum  \
# 0   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 1   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 2   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 3   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 4   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 5   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 6   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 7   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 8   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 9   EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 10  EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 11  EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 12  EX_glc__D_e, EX_sucr_e           0.0                   0.0
# 13  EX_glc__D_e, EX_sucr_e           0.0                   0.0
# ...

# %%
PPP_AA.plot(x='EX_sucr_e', y='flux_maximum', ylabel="Artemisinic Acid")
# Out:
# <AxesSubplot:xlabel='EX_sucr_e', ylabel='Artemisinic Acid'>
