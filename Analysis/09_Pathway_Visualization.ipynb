# %% [markdown]
# Pathway visulization shows the carbon metabolic map of S. cervisia, With us adding the reactions relevant for the MVA pathway which produces the precourser FPP for the hetreologous pathway. It should be noted that we could not add our hetrologus pathway, becuase there is not a metabolic model of Artemisia annua. The patway was constructed using the Github version of escher.build.

# %%
from PIL import Image
img = Image.open("Pictures\Pathway_Visualization.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2048x3420>
