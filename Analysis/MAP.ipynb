# %%
from skimage import io
 
img = io.imread("metabolism.map.png")

# %%
from PIL import Image
img = Image.open("metabolism.map.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2048x3420>
