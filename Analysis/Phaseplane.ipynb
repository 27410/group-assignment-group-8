# %%
from cobra.flux_analysis.phenotype_phase_plane import production_envelope
# %run Model_CFE.ipynb
# Out:
# ADS: frdp_c --> AMOR + ppi_c
# CPR1_CYP71AV1: AMOR + h_c + nadph_c + o2_c --> AAOH + h2o_c + nadp_c
# ADH1: AAOH + nad_c --> AAld + h_c + nadh_c
# ALDH1: AAld + h2o_c + nadp_c --> AA + h_c + nadph_c

# %%
#defining relavent reactions needed
Glucosee=iMM904.reactions.EX_glc__D_e
O2=iMM904.reactions.EX_o2_e
Growth = iMM904.reactions.BIOMASS_SC5_notrace

# %%
#Changning flux of glucose
Medium=iMM904.medium
Medium['EX_glc__D_e']=10000
iMM904.reactions.EX_glc__D_e.bounds=-1,0

Production_biomass = production_envelope(iMM904,
                    reactions=[Glucosee],
                    objective=Growth)
Production_biomass
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0    EX_glc__D_e           0.0                   0.0                 NaN
# 1    EX_glc__D_e           0.0                   0.0                 NaN
# 2    EX_glc__D_e           0.0                   0.0                 NaN
# 3    EX_glc__D_e           0.0                   0.0                 NaN
# 4    EX_glc__D_e           0.0                   0.0                 NaN
# 5    EX_glc__D_e           0.0                   0.0                 NaN
# 6    EX_glc__D_e           0.0                   0.0                 NaN
# 7    EX_glc__D_e           0.0                   0.0                 NaN
# 8    EX_glc__D_e           0.0                   0.0                 NaN
# 9    EX_glc__D_e           0.0                   0.0                 NaN
# 10   EX_glc__D_e           0.0                   0.0                 NaN
# 11   EX_glc__D_e           0.0                   0.0                 NaN
# 12   EX_glc__D_e           0.0                   0.0                 NaN
# 13   EX_glc__D_e           0.0                   0.0                 NaN
# 14   EX_glc__D_e           0.0                   0.0                 NaN
# 15   EX_glc__D_e           0.0                   0.0                 NaN
# 16   EX_glc__D_e           0.0                   0.0                 NaN
# 17   EX_glc__D_e           0.0                   0.0                 NaN
# 18   EX_glc__D_e           0.0                   0.0                 NaN
# 19   EX_glc__D_e           0.0                   0.0                 NaN
#
#     flux_maximum  carbon_yield_maximum  mass_yield_maximum  EX_glc__D_e
# 0       0.073433          7.694630e+00                 NaN    -1.000000
# 1       0.072221          7.961979e+00                 NaN    -0.950464
# 2       0.071008          8.258727e+00                 NaN    -0.900929
# 3       0.069796          8.590005e+00                 NaN    -0.851393
# 4       0.068583          8.962214e+00                 NaN    -0.801858
# 5       0.067371          9.383438e+00                 NaN    -0.752322
# 6       0.063150          9.415537e+00                 NaN    -0.702786
# 7       0.058293          9.350318e+00                 NaN    -0.653251
# 8       0.053435          9.274397e+00                 NaN    -0.603715
# 9       0.048577          9.184903e+00                 NaN    -0.554180
# 10      0.043719          9.077840e+00                 NaN    -0.504644
# 11      0.038862          8.947470e+00                 NaN    -0.455108
# 12      0.034004          8.785255e+00                 NaN    -0.405573
# 13      0.029146          8.577901e+00                 NaN    -0.356037
# 14      0.024289          8.303523e+00                 NaN    -0.306502
# 15      0.019431          7.923362e+00                 NaN    -0.256966
# 16      0.014573          7.361631e+00                 NaN    -0.207430
# 17      0.009715          6.447442e+00                 NaN    -0.157895
# 18      0.004858          4.697422e+00                 NaN    -0.108359
# 19      0.000000          4.883707e-13                 NaN    -0.058824

# %%
Production_biomass.plot(x='EX_glc__D_e', y='flux_maximum', xlabel="Glucose uptake [mmol/g DW/h]", ylabel="Biomass objective [1/h]", grid = True)
# Out:
# <AxesSubplot:xlabel='Glucose uptake [mmol/g DW/h]', ylabel='Biomass objective [1/h]'>
