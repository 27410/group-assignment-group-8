# %%
from cobra.flux_analysis.phenotype_phase_plane import production_envelope
# %run Model_CFE.ipynb
# Out:
# ADS: frdp_c --> AMOR + ppi_c
# CPR1_CYP71AV1: AMOR + h_c + nadph_c + o2_c --> AAOH + h2o_c + nadp_c
# ADH1: AAOH + nad_c --> AAld + h_c + nadh_c
# ALDH1: AAld + h2o_c + nadp_c --> AA + h_c + nadph_c

# %% [markdown]
# Constructing the phenotype phase plane plot for the biomass objective:

# %%
#Changning flux of glucose
Medium=iMM904.medium
Medium['EX_glc__D_e']=20
iMM904.reactions.EX_glc__D_e.bounds=-20,1000

PPP_biomass = production_envelope(iMM904,
                    reactions=[iMM904.reactions.EX_glc__D_e],
                    objective=iMM904.reactions.BIOMASS_SC5_notrace)
PPP_biomass
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0    EX_glc__D_e           0.0                   0.0                 NaN
# 1    EX_glc__D_e           0.0                   0.0                 NaN
# 2    EX_glc__D_e           0.0                   0.0                 NaN
# 3    EX_glc__D_e           0.0                   0.0                 NaN
# 4    EX_glc__D_e           0.0                   0.0                 NaN
# 5    EX_glc__D_e           0.0                   0.0                 NaN
# 6    EX_glc__D_e           0.0                   0.0                 NaN
# 7    EX_glc__D_e           0.0                   0.0                 NaN
# 8    EX_glc__D_e           0.0                   0.0                 NaN
# 9    EX_glc__D_e           0.0                   0.0                 NaN
# 10   EX_glc__D_e           0.0                   0.0                 NaN
# 11   EX_glc__D_e           0.0                   0.0                 NaN
# 12   EX_glc__D_e           0.0                   0.0                 NaN
# 13   EX_glc__D_e           0.0                   0.0                 NaN
# 14   EX_glc__D_e           0.0                   0.0                 NaN
# 15   EX_glc__D_e           0.0                   0.0                 NaN
# 16   EX_glc__D_e           0.0                   0.0                 NaN
# 17   EX_glc__D_e           0.0                   0.0                 NaN
# 18   EX_glc__D_e           0.0                   0.0                 NaN
# 19   EX_glc__D_e           0.0                   0.0                 NaN
#
#     flux_maximum  carbon_yield_maximum  mass_yield_maximum  EX_glc__D_e
# 0       0.517919          2.713474e+00                 NaN   -20.000000
# 1       0.494706          2.735401e+00                 NaN   -18.950464
# 2       0.471493          2.759900e+00                 NaN   -17.900929
# 3       0.448227          2.787124e+00                 NaN   -16.851393
# 4       0.424430          2.814437e+00                 NaN   -15.801858
# 5       0.400171          2.842362e+00                 NaN   -14.752322
# 6       0.375448          2.871007e+00                 NaN   -13.702786
# 7       0.350695          2.904166e+00                 NaN   -12.653251
# 8       0.325943          2.943324e+00                 NaN   -11.603715
# 9       0.301032          2.988694e+00                 NaN   -10.554180
# 10      0.276097          3.043825e+00                 NaN    -9.504644
# 11      0.251162          3.112642e+00                 NaN    -8.455108
# 12      0.226228          3.200964e+00                 NaN    -7.405573
# 13      0.201293          3.318455e+00                 NaN    -6.356037
# 14      0.176358          3.482422e+00                 NaN    -5.306502
# 15      0.151424          3.727239e+00                 NaN    -4.256966
# 16      0.126489          4.132274e+00                 NaN    -3.207430
# 17      0.101554          4.931303e+00                 NaN    -2.157895
# 18      0.076086          7.193118e+00                 NaN    -1.108359
# 19      0.000000          2.244761e-11                 NaN    -0.058824

# %%
PPP_biomass.plot(x='EX_glc__D_e', y='flux_maximum', ylabel="Biomass")
# Out:
# <AxesSubplot:xlabel='EX_glc__D_e', ylabel='Biomass'>

# %% [markdown]
# Constructing the phenotype phase plane plot for Artemisinic Acid:

# %%
PPP_AA = production_envelope(iMM904,
                    reactions=[iMM904.reactions.EX_glc__D_e],
                    objective=iMM904.reactions.ALDH1)
PPP_AA
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0    EX_glc__D_e           0.0                   0.0                 NaN
# 1    EX_glc__D_e           0.0                   0.0                 NaN
# 2    EX_glc__D_e           0.0                   0.0                 NaN
# 3    EX_glc__D_e           0.0                   0.0                 NaN
# 4    EX_glc__D_e           0.0                   0.0                 NaN
# 5    EX_glc__D_e           0.0                   0.0                 NaN
# 6    EX_glc__D_e           0.0                   0.0                 NaN
# 7    EX_glc__D_e           0.0                   0.0                 NaN
# 8    EX_glc__D_e           0.0                   0.0                 NaN
# 9    EX_glc__D_e           0.0                   0.0                 NaN
# 10   EX_glc__D_e           0.0                   0.0                 NaN
# 11   EX_glc__D_e           0.0                   0.0                 NaN
# 12   EX_glc__D_e           0.0                   0.0                 NaN
# 13   EX_glc__D_e           0.0                   0.0                 NaN
# 14   EX_glc__D_e           0.0                   0.0                 NaN
# 15   EX_glc__D_e           0.0                   0.0                 NaN
# 16   EX_glc__D_e           0.0                   0.0                 NaN
# 17   EX_glc__D_e           0.0                   0.0                 NaN
# 18   EX_glc__D_e           0.0                   0.0                 NaN
# 19   EX_glc__D_e           0.0                   0.0                 NaN
#
#     flux_maximum  carbon_yield_maximum  mass_yield_maximum  EX_glc__D_e
# 0       1.439394          4.318182e-01                 NaN   -20.000000
# 1       1.375786          4.355943e-01                 NaN   -18.950464
# 2       1.312178          4.398132e-01                 NaN   -17.900929
# 3       1.248569          4.445576e-01                 NaN   -16.851393
# 4       1.184961          4.499323e-01                 NaN   -15.801858
# 5       1.121353          4.560717e-01                 NaN   -14.752322
# 6       1.057745          4.631516e-01                 NaN   -13.702786
# 7       0.994136          4.714060e-01                 NaN   -12.653251
# 8       0.930528          4.811536e-01                 NaN   -11.603715
# 9       0.866920          4.928398e-01                 NaN   -10.554180
# 10      0.803312          5.071069e-01                 NaN    -9.504644
# 11      0.739704          5.249159e-01                 NaN    -8.455108
# 12      0.676095          5.477729e-01                 NaN    -7.405573
# 13      0.612487          5.781783e-01                 NaN    -6.356037
# 14      0.548879          6.206110e-01                 NaN    -5.306502
# 15      0.485271          6.839669e-01                 NaN    -4.256966
# 16      0.421662          7.887855e-01                 NaN    -3.207430
# 17      0.354370          9.853227e-01                 NaN    -2.157895
# 18      0.252311          1.365862e+00                 NaN    -1.108359
# 19      0.000000          1.124967e-13                 NaN    -0.058824

# %%
PPP_AA.plot(x='EX_glc__D_e', y='flux_maximum', ylabel="Biomass")
# Out:
# <AxesSubplot:xlabel='EX_glc__D_e', ylabel='Biomass'>
